# %% [markdown]
# In this notebook you will see how to load data from a file and perform some calculations on it. We will walk you step-by-step.

# %% [markdown]
# ##Reading Data

# %% [markdown]
# **Step 1:** To access your Google Drive files in Colab, you need to run the following cell:

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('/content/drive/My Drive/Datasets')
# !ls
# Out:
# temperature_boston_monthly_5years.csv

# %% [markdown]
# **Step 2:** To read in the values from the temperature file into our Colab notebook, you can run the lines of code in the following cell:

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
df = pd.read_csv('/content/drive/MyDrive/Datasets/temperature_boston_monthly_5years.csv')

# %%
df
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 0   North America      US  Massachusetts  Boston      1    1  2015
# 1   North America      US  Massachusetts  Boston      2    1  2015
# 2   North America      US  Massachusetts  Boston      3    1  2015
# 3   North America      US  Massachusetts  Boston      4    1  2015
# 4   North America      US  Massachusetts  Boston      5    1  2015
# 5   North America      US  Massachusetts  Boston      6    1  2015
# 6   North America      US  Massachusetts  Boston      7    1  2015
# 7   North America      US  Massachusetts  Boston      8    1  2015
# 8   North America      US  Massachusetts  Boston      9    1  2015
# 9   North America      US  Massachusetts  Boston     10    1  2015
# 10  North America      US  Massachusetts  Boston     11    1  2015
# 11  North America      US  Massachusetts  Boston     12    1  2015
# 12  North America      US  Massachusetts  Boston      1    1  2016
# ...

# %% [markdown]
# ##Accessing Rows and Columns

# %%
df.loc[28]
# Out:
# Region            North America
# Country                      US
# State             Massachusetts
# City                     Boston
# Month                         5
# Day                           1
# Year                       2017
# AvgTemperature             46.9
# Name: 28, dtype: object

# %%
df['AvgTemperature']
# Out:
# 0     26.1
# 1     19.3
# 2     23.0
# 3     39.0
# 4     45.4
# 5     48.2
# 6     69.5
# 7     78.7
# 8     75.6
# 9     57.7
# 10    52.9
# 11    37.7
# 12    39.1
# 13    49.5
# 14    41.6
# 15    63.1
# 16    48.2
# 17    68.8
# 18    75.5
# 19    70.6
# 20    74.4
# 21    56.9
# 22    42.4
# 23    50.2
# 24    40.0
# 25    32.2
# 26    52.8
# 27    35.2
# 28    46.9
# 29    66.5
# 30    76.1
# 31    74.4
# 32    62.3
# 33    54.7
# 34    48.3
# 35    46.3
# 36     5.6
# 37    34.7
# 38    47.5
# 39    47.9
# 40    51.5
# 41    70.4
# 42    82.4
# 43    74.7
# 44    68.2
# 45    61.6
# 46    57.9
# 47    38.7
# 48    47.2
# 49    16.0
# 50    29.4
# 51    42.3
# 52    50.6
# 53    60.0
# 54    71.0
# 55    79.5
# 56    68.5
# 57    62.2
# 58    62.2
# 59    28.6
# Name: AvgTemperature, dtype: float64

# %%
df.loc[10:15]
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 10  North America      US  Massachusetts  Boston     11    1  2015
# 11  North America      US  Massachusetts  Boston     12    1  2015
# 12  North America      US  Massachusetts  Boston      1    1  2016
# 13  North America      US  Massachusetts  Boston      2    1  2016
# 14  North America      US  Massachusetts  Boston      3    1  2016
# 15  North America      US  Massachusetts  Boston      4    1  2016
#
#     AvgTemperature
# 10            52.9
# 11            37.7
# 12            39.1
# 13            49.5
# 14            41.6
# 15            63.1

# %%
columns = ["Month", "AvgTemperature"]
df[columns]
# Out:
#     Month  AvgTemperature
# 0       1            26.1
# 1       2            19.3
# 2       3            23.0
# 3       4            39.0
# 4       5            45.4
# 5       6            48.2
# 6       7            69.5
# 7       8            78.7
# 8       9            75.6
# 9      10            57.7
# 10     11            52.9
# 11     12            37.7
# 12      1            39.1
# 13      2            49.5
# 14      3            41.6
# 15      4            63.1
# 16      5            48.2
# 17      6            68.8
# 18      7            75.5
# 19      8            70.6
# 20      9            74.4
# 21     10            56.9
# 22     11            42.4
# 23     12            50.2
# 24      1            40.0
# 25      2            32.2
# 26      3            52.8
# 27      4            35.2
# 28      5            46.9
# 29      6            66.5
# 30      7            76.1
# 31      8            74.4
# 32      9            62.3
# 33     10            54.7
# ...

# %%
df[["Month", "AvgTemperature"]]
# Out:
#     Month  AvgTemperature
# 0       1            26.1
# 1       2            19.3
# 2       3            23.0
# 3       4            39.0
# 4       5            45.4
# 5       6            48.2
# 6       7            69.5
# 7       8            78.7
# 8       9            75.6
# 9      10            57.7
# 10     11            52.9
# 11     12            37.7
# 12      1            39.1
# 13      2            49.5
# 14      3            41.6
# 15      4            63.1
# 16      5            48.2
# 17      6            68.8
# 18      7            75.5
# 19      8            70.6
# 20      9            74.4
# 21     10            56.9
# 22     11            42.4
# 23     12            50.2
# 24      1            40.0
# 25      2            32.2
# 26      3            52.8
# 27      4            35.2
# 28      5            46.9
# 29      6            66.5
# 30      7            76.1
# 31      8            74.4
# 32      9            62.3
# 33     10            54.7
# ...

# %% [markdown]
# ##Sorting DataFrames

# %%
df_sorted = df.sort_values('AvgTemperature', ascending = False)
df_sorted
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 42  North America      US  Massachusetts  Boston      7    1  2018
# 55  North America      US  Massachusetts  Boston      8    1  2019
# 7   North America      US  Massachusetts  Boston      8    1  2015
# 30  North America      US  Massachusetts  Boston      7    1  2017
# 8   North America      US  Massachusetts  Boston      9    1  2015
# 18  North America      US  Massachusetts  Boston      7    1  2016
# 43  North America      US  Massachusetts  Boston      8    1  2018
# 20  North America      US  Massachusetts  Boston      9    1  2016
# 31  North America      US  Massachusetts  Boston      8    1  2017
# 54  North America      US  Massachusetts  Boston      7    1  2019
# 19  North America      US  Massachusetts  Boston      8    1  2016
# 41  North America      US  Massachusetts  Boston      6    1  2018
# 6   North America      US  Massachusetts  Boston      7    1  2015
# ...

# %%
df_sorted.reset_index(drop = True)
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 0   North America      US  Massachusetts  Boston      7    1  2018
# 1   North America      US  Massachusetts  Boston      8    1  2019
# 2   North America      US  Massachusetts  Boston      8    1  2015
# 3   North America      US  Massachusetts  Boston      7    1  2017
# 4   North America      US  Massachusetts  Boston      9    1  2015
# 5   North America      US  Massachusetts  Boston      7    1  2016
# 6   North America      US  Massachusetts  Boston      8    1  2018
# 7   North America      US  Massachusetts  Boston      9    1  2016
# 8   North America      US  Massachusetts  Boston      8    1  2017
# 9   North America      US  Massachusetts  Boston      7    1  2019
# 10  North America      US  Massachusetts  Boston      8    1  2016
# 11  North America      US  Massachusetts  Boston      6    1  2018
# 12  North America      US  Massachusetts  Boston      7    1  2015
# ...

# %% [markdown]
# ##Running Built-in Functions on the Data

# %%
df['AvgTemperature'].mean()
# Out:
# 52.46166666666666

# %%
df['AvgTemperature'].max()
# Out:
# 82.4

# %%
df['AvgTemperature'].count()
# Out:
# 60

# %% [markdown]
# ##Filtering Data

# %%
condition = df['AvgTemperature'] > 75
condition
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55     True
# 56    False
# 57    False
# 58    False
# 59    False
# Name: AvgTemperature, dtype: bool

# %%
df.loc[condition]
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 7   North America      US  Massachusetts  Boston      8    1  2015
# 8   North America      US  Massachusetts  Boston      9    1  2015
# 18  North America      US  Massachusetts  Boston      7    1  2016
# 30  North America      US  Massachusetts  Boston      7    1  2017
# 42  North America      US  Massachusetts  Boston      7    1  2018
# 55  North America      US  Massachusetts  Boston      8    1  2019
#
#     AvgTemperature
# 7             78.7
# 8             75.6
# 18            75.5
# 30            76.1
# 42            82.4
# 55            79.5

# %%
df.loc[(df["AvgTemperature"] > 75) & (df["Month"] == 8)]
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 7   North America      US  Massachusetts  Boston      8    1  2015
# 55  North America      US  Massachusetts  Boston      8    1  2019
#
#     AvgTemperature
# 7             78.7
# 55            79.5

# %%
df.loc[df['AvgTemperature'] < 50].count()
# Out:
# Region            28
# Country           28
# State             28
# City              28
# Month             28
# Day               28
# Year              28
# AvgTemperature    28
# dtype: int64

# %%
df.loc[df["Year"] == 2015].mean(numeric_only=True)
# Out:
# Month                6.500000
# Day                  1.000000
# Year              2015.000000
# AvgTemperature      47.758333
# dtype: float64

# %% [markdown]
# ##Grouping Data

# %%
df.groupby('Year').mean(numeric_only = True)
# Out:
#       Month  Day  AvgTemperature
# Year
# 2015    6.5  1.0       47.758333
# 2016    6.5  1.0       56.691667
# 2017    6.5  1.0       52.975000
# 2018    6.5  1.0       53.425000
# 2019    6.5  1.0       51.458333

# %%
df.groupby("Year").mean(numeric_only=True).loc[2017]
# Out:
# Month              6.500
# Day                1.000
# AvgTemperature    52.975
# Name: 2017, dtype: float64

# %%
df.groupby('Year').mean(numeric_only=True)["AvgTemperature"]
# Out:
# Year
# 2015    47.758333
# 2016    56.691667
# 2017    52.975000
# 2018    53.425000
# 2019    51.458333
# Name: AvgTemperature, dtype: float64

# %%
allmaxtemps = df.groupby("Year").max()
allmaxtemps
# Out:
#              Region Country          State    City  Month  Day  AvgTemperature
# Year
# 2015  North America      US  Massachusetts  Boston     12    1            78.7
# 2016  North America      US  Massachusetts  Boston     12    1            75.5
# 2017  North America      US  Massachusetts  Boston     12    1            76.1
# 2018  North America      US  Massachusetts  Boston     12    1            82.4
# 2019  North America      US  Massachusetts  Boston     12    1            79.5

# %%
allmaxtemps.loc[2015]
# Out:
# Region            North America
# Country                      US
# State             Massachusetts
# City                     Boston
# Month                        12
# Day                           1
# AvgTemperature             78.7
# Name: 2015, dtype: object

# %%
temp2015 = allmaxtemps.loc[2015]['AvgTemperature']
temp2015
# Out:
# 78.7

# %%
condition = (df["AvgTemperature"] == temp2015)
df.loc[condition]
# Out:
#           Region Country          State    City  Month  Day  Year  \
# 7  North America      US  Massachusetts  Boston      8    1  2015
#
#    AvgTemperature
# 7            78.7

# %% [markdown]
# ##Finding Correlations between Data Columns

# %%
df.corr()
# Out:
#                        Month  Day          Year  AvgTemperature
# Month           1.000000e+00  NaN  2.168623e-14        0.452060
# Day                      NaN  NaN           NaN             NaN
# Year            2.168623e-14  NaN  1.000000e+00        0.033659
# AvgTemperature  4.520600e-01  NaN  3.365939e-02        1.000000

# %%
df
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 0   North America      US  Massachusetts  Boston      1    1  2015
# 1   North America      US  Massachusetts  Boston      2    1  2015
# 2   North America      US  Massachusetts  Boston      3    1  2015
# 3   North America      US  Massachusetts  Boston      4    1  2015
# 4   North America      US  Massachusetts  Boston      5    1  2015
# 5   North America      US  Massachusetts  Boston      6    1  2015
# 6   North America      US  Massachusetts  Boston      7    1  2015
# 7   North America      US  Massachusetts  Boston      8    1  2015
# 8   North America      US  Massachusetts  Boston      9    1  2015
# 9   North America      US  Massachusetts  Boston     10    1  2015
# 10  North America      US  Massachusetts  Boston     11    1  2015
# 11  North America      US  Massachusetts  Boston     12    1  2015
# 12  North America      US  Massachusetts  Boston      1    1  2016
# ...

# %% [markdown]
# ## Visualizing Data
# ### x-y plot

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["AvgTemperature"])

# %%
_= plt.plot(df["AvgTemperature"])

# %%
_= plt.plot(df["Month"], color = "orange")

# %%
_= plt.plot(df["AvgTemperature"])
_= plt.plot(df["Month"])

# %% [markdown]
# ## Scatter Plot

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(range(len(df["AvgTemperature"])), df["AvgTemperature"])

# %% [markdown]
# ## Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["AvgTemperature"], bins = 10)
# Out:
# (array([ 1.,  2.,  3.,  4.,  8., 13.,  6.,  7., 10.,  6.]),
#  array([ 5.6 , 13.28, 20.96, 28.64, 36.32, 44.  , 51.68, 59.36, 67.04,
#         74.72, 82.4 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

# %%
df["Region"] = df["Region"].dropna()

# %%
df["Country"] = df["Country"].dropna()

# %%
df["State"] = df["State"].dropna()

# %%
df["City"] = df["City"].dropna()

# %%
df["Month"] = df["Month"].dropna()

# %%
df["Day"] = df["Day"].dropna()

# %%
df["Year"] = df["Year"].dropna()

# %%
df["AvgTemperature"] = df["AvgTemperature"].dropna()

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'State', 'City', 'Month', 'Day', 'Year',
#        'AvgTemperature'],
#       dtype='object')

# %%
print("then repeat 78 80's story be nazeer ki zuban kat do")
# Out:
# then repeat 78 80's story be nazeer ki zuban kat do

# %%
c = df.corr()
c
# Out:
#                        Month  Day          Year  AvgTemperature
# Month           1.000000e+00  NaN  2.168623e-14        0.452060
# Day                      NaN  NaN           NaN             NaN
# Year            2.168623e-14  NaN  1.000000e+00        0.033659
# AvgTemperature  4.520600e-01  NaN  3.365939e-02        1.000000

# %%
df
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 0   North America      US  Massachusetts  Boston      1    1  2015
# 1   North America      US  Massachusetts  Boston      2    1  2015
# 2   North America      US  Massachusetts  Boston      3    1  2015
# 3   North America      US  Massachusetts  Boston      4    1  2015
# 4   North America      US  Massachusetts  Boston      5    1  2015
# 5   North America      US  Massachusetts  Boston      6    1  2015
# 6   North America      US  Massachusetts  Boston      7    1  2015
# 7   North America      US  Massachusetts  Boston      8    1  2015
# 8   North America      US  Massachusetts  Boston      9    1  2015
# 9   North America      US  Massachusetts  Boston     10    1  2015
# 10  North America      US  Massachusetts  Boston     11    1  2015
# 11  North America      US  Massachusetts  Boston     12    1  2015
# 12  North America      US  Massachusetts  Boston      1    1  2016
# ...

# %%
import numpy as np

# %%
df = df.select_dtypes(include=np.number)

# %%
c = df.corr()

# %%
c
# Out:
#                        Month  Day          Year  AvgTemperature
# Month           1.000000e+00  NaN  2.168623e-14        0.452060
# Day                      NaN  NaN           NaN             NaN
# Year            2.168623e-14  NaN  1.000000e+00        0.033659
# AvgTemperature  4.520600e-01  NaN  3.365939e-02        1.000000

# %%
_= sns.heatmap(c)

# %% [markdown]
# ## Bad Data

# %% [markdown]
# Now we will take a look at some data with problematic values in it. To do that, we read a new csv file with temperatures from across the world, called `temperature.csv`

# %%
df2 = pd.read_csv("/content/drive/MyDrive/Datasets/temperature_boston_monthly_5years.csv")
df2
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 0   North America      US  Massachusetts  Boston      1    1  2015
# 1   North America      US  Massachusetts  Boston      2    1  2015
# 2   North America      US  Massachusetts  Boston      3    1  2015
# 3   North America      US  Massachusetts  Boston      4    1  2015
# 4   North America      US  Massachusetts  Boston      5    1  2015
# 5   North America      US  Massachusetts  Boston      6    1  2015
# 6   North America      US  Massachusetts  Boston      7    1  2015
# 7   North America      US  Massachusetts  Boston      8    1  2015
# 8   North America      US  Massachusetts  Boston      9    1  2015
# 9   North America      US  Massachusetts  Boston     10    1  2015
# 10  North America      US  Massachusetts  Boston     11    1  2015
# 11  North America      US  Massachusetts  Boston     12    1  2015
# 12  North America      US  Massachusetts  Boston      1    1  2016
# ...

# %% [markdown]
# ### Missing Data

# %%
na_vals = df2.isna()
na_vals
# Out:
#     Region  Country  State   City  Month    Day   Year  AvgTemperature
# 0    False    False  False  False  False  False  False           False
# 1    False    False  False  False  False  False  False           False
# 2    False    False  False  False  False  False  False           False
# 3    False    False  False  False  False  False  False           False
# 4    False    False  False  False  False  False  False           False
# 5    False    False  False  False  False  False  False           False
# 6    False    False  False  False  False  False  False           False
# 7    False    False  False  False  False  False  False           False
# 8    False    False  False  False  False  False  False           False
# 9    False    False  False  False  False  False  False           False
# 10   False    False  False  False  False  False  False           False
# 11   False    False  False  False  False  False  False           False
# ...

# %%
na_cols = na_vals.any()
na_cols
# Out:
# Region            False
# Country           False
# State             False
# City              False
# Month             False
# Day               False
# Year              False
# AvgTemperature    False
# dtype: bool

# %%
print("Currupt doggy want mama")
# Out:
# Currupt doggy want mama

# %%
df2.columns[na_cols].to_list()
# Out:
# []

# %%
df2 = df2.dropna()
df2
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 0   North America      US  Massachusetts  Boston      1    1  2015
# 1   North America      US  Massachusetts  Boston      2    1  2015
# 2   North America      US  Massachusetts  Boston      3    1  2015
# 3   North America      US  Massachusetts  Boston      4    1  2015
# 4   North America      US  Massachusetts  Boston      5    1  2015
# 5   North America      US  Massachusetts  Boston      6    1  2015
# 6   North America      US  Massachusetts  Boston      7    1  2015
# 7   North America      US  Massachusetts  Boston      8    1  2015
# 8   North America      US  Massachusetts  Boston      9    1  2015
# 9   North America      US  Massachusetts  Boston     10    1  2015
# 10  North America      US  Massachusetts  Boston     11    1  2015
# 11  North America      US  Massachusetts  Boston     12    1  2015
# 12  North America      US  Massachusetts  Boston      1    1  2016
# ...

# %%
df2.groupby("Country").min()
# Out:
#                 Region          State    City  Month  Day  Year  \
# Country
# US       North America  Massachusetts  Boston      1    1  2015
#
#          AvgTemperature
# Country
# US                  5.6

# %% [markdown]
# ### Incorrect Data

# %%
df2.loc[df2["AvgTemperature"] == -99]
# Out:
# Empty DataFrame
# Columns: [Region, Country, State, City, Month, Day, Year, AvgTemperature]
# Index: []

# %%
df2.loc[df2["AvgTemperature"] == 5.6]
# Out:
#            Region Country          State    City  Month  Day  Year  \
# 36  North America      US  Massachusetts  Boston      1    1  2018
#
#     AvgTemperature
# 36             5.6
